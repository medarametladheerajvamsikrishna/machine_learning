# %% [markdown]
# ![Screenshot 2026-08-18 213613.png](data:image/png;base64,...)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import kagglehub
import os

# %%
path = kagglehub.dataset_download(
    "adelanseur/taxi-trips-chicago-2024"
)

print("Path to dataset files:", path)
# Out:
# Downloading to /root/.cache/kagglehub/datasets/adelanseur/taxi-trips-chicago-2024/1.archive...
# 100%|██████████| 111M/111M [00:00<00:00, 186MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/adelanseur/taxi-trips-chicago-2024/versions/1

# %%
print(os.listdir(path))
# Out:
# ['Taxi_Trips_-_2024_20240408.csv']

# %%
data = pd.read_csv(
    f"{path}/Taxi_Trips_-_2024_20240408.csv"
)

data.head()
# Out:
#                                     Trip ID  \
# 0  0287f53fedcde6b0af9aab9e32cbd2cadb337eaa
# 1  1f0034299b914fd7b45002568576a353c83acb2f
# 2  01a0b77b722a0b91f45cb4fc90b3e64f76fd0681
# 3  14aff2071ac81c6450a8f8b0e1534497da900197
# 4  16d3a633e2f380cee4a7fa4677db163b6e91255d
#
#                                              Taxi ID    Trip Start Timestamp  \
# 0  e54db25f18193a08f1f5754515e8c338480e04fb938ed3...  03/01/2024 12:00:00 AM
# 1  4a263f78f56815be4acd38658af8fc1824ce4e15f7ec81...  03/01/2024 12:00:00 AM
# 2  4f1e94982e6851725add382f7981d64006ae7c38f3664f...  03/01/2024 12:00:00 AM
# 3  de8e8659ceb9eb0da842a46b60c0a5207098ac69fc23ab...  03/01/2024 12:00:00 AM
# 4  d79d3e19a1d5f6cb0cd4449d5579412262a2f1b182799d...  03/01/2024 12:00:00 AM
#
#        Trip End Timestamp  Trip Seconds  Trip Miles  Pickup Census Tract  \
# 0  03/01/2024 12:00:00 AM          15.0        0.09                  NaN
# 1  03/01/2024 12:15:00 AM         900.0        3.00                  NaN
# 2  03/01/2024 12:00:00 AM         711.0        5.84                  NaN
# 3  03/01/2024 12:30:00 AM        1770.0       13.36                  NaN
# 4  03/01/2024 12:15:00 AM         849.0        6.13                  NaN
#
#    Dropoff Census Tract  Pickup Community Area  Dropoff Community Area  ...  \
# 0                   NaN                    8.0                     8.0  ...
# 1                   NaN                   24.0                     8.0  ...
# 2                   NaN                   56.0                     NaN  ...
# 3                   NaN                   76.0                     3.0  ...
# 4                   NaN                    8.0                     3.0  ...
#
#    Extras  Trip Total  Payment Type                    Company  \
# 0    35.0       38.75   Credit Card               City Service
# 1     0.0       12.00          Cash  Taxi Affiliation Services
# 2     5.0       26.70   Credit Card               City Service
# 3     4.0       47.10   Credit Card                   Sun Taxi
# 4     0.0       22.82        Mobile                5 Star Taxi
#
#    Pickup Centroid Latitude Pickup Centroid Longitude  \
# 0                 41.899602                -87.633308
# 1                 41.901207                -87.676356
# 2                 41.792592                -87.769615
# 3                 41.980264                -87.913625
# 4                 41.899602                -87.633308
#
#                Pickup Centroid Location  Dropoff Centroid Latitude  \
# 0   POINT (-87.6333080367 41.899602111)                  41.899602
# 1  POINT (-87.6763559892 41.9012069941)                  41.899602
# 2  POINT (-87.7696154528 41.7925923603)                        NaN
# 3   POINT (-87.913624596 41.9802643146)                  41.965812
# 4   POINT (-87.6333080367 41.899602111)                  41.965812
#
#    Dropoff Centroid Longitude           Dropoff Centroid  Location
# 0                  -87.633308  POINT (-87.6333080367 41.899602111)
# 1                  -87.633308  POINT (-87.6333080367 41.899602111)
# 2                         NaN                                  NaN
# 3                  -87.655879   POINT (-87.6558787862 41.96581197)
# 4                  -87.655879   POINT (-87.6558787862 41.96581197)
#
# [5 rows x 23 columns]

# %%
df = pd.read_csv(
    f"{path}/Taxi_Trips_-_2024_20240408.csv"
)

# %%
print("Number of rows:", df.shape[0])

print("Number of columns:", df.shape[1])

print("\nColumn names:")

print(df.columns.tolist())
# Out:
# Number of rows: 865247
# Number of columns: 23
#
# Column names:
# ['Trip ID', 'Taxi ID', 'Trip Start Timestamp', 'Trip End Timestamp', 'Trip Seconds', 'Trip Miles', 'Pickup Census Tract', 'Dropoff Census Tract', 'Pickup Community Area', 'Dropoff Community Area', 'Fare', 'Tips', 'Tolls', 'Extras', 'Trip Total', 'Payment Type', 'Company', 'Pickup Centroid Latitude', 'Pickup Centroid Longitude', 'Pickup Centroid Location', 'Dropoff Centroid Latitude', 'Dropoff Centroid Longitude', 'Dropoff Centroid  Location']

# %%
df.describe()
# Out:
#         Trip Seconds     Trip Miles  Pickup Census Tract  \
# count  865078.000000  865241.000000         3.272510e+05
# mean     1150.532018       6.563330         1.703152e+10
# std      1584.243513       8.279528         3.721479e+05
# min         0.000000       0.000000         1.703101e+10
# 25%       459.000000       0.910000         1.703108e+10
# 50%       900.000000       3.070000         1.703132e+10
# 75%      1591.000000      11.710000         1.703198e+10
# max     86340.000000    3093.470000         1.703198e+10
#
#        Dropoff Census Tract  Pickup Community Area  Dropoff Community Area  \
# count          3.138540e+05          842052.000000           781394.000000
# mean           1.703141e+10              36.660485               25.853590
# std            3.392339e+05              26.416845               20.501911
# min            1.703101e+10               1.000000                1.000000
# 25%            1.703108e+10               8.000000                8.000000
# 50%            1.703132e+10              32.000000               28.000000
# 75%            1.703184e+10              69.000000               32.000000
# max            1.703198e+10              77.000000               77.000000
#
#                 Fare           Tips          Tolls         Extras  \
# count  863202.000000  863202.000000  863202.000000  863202.000000
# mean       22.057441       2.761349       0.063232       2.149285
# std        25.145823       4.132953      12.955213      19.319780
# min         0.000000       0.000000       0.000000       0.000000
# 25%         8.000000       0.000000       0.000000       0.000000
# 50%        15.750000       0.000000       0.000000       0.000000
# 75%        33.750000       4.000000       0.000000       3.000000
# max      9999.750000     200.000000    4444.440000    5051.100000
#
#           Trip Total  Pickup Centroid Latitude  Pickup Centroid Longitude  \
# count  863202.000000             842281.000000              842281.000000
# mean       27.204886                 41.902214                 -87.704695
# std        40.989308                  0.066429                   0.115525
# min         0.000000                 41.660136                 -87.913625
# 25%        10.000000                 41.878866                 -87.769615
# 50%        18.780000                 41.898332                 -87.642649
# 75%        40.900000                 41.979071                 -87.626146
# max      9999.750000                 42.021224                 -87.534903
#
#        Dropoff Centroid Latitude  Dropoff Centroid Longitude
# count              785572.000000               785572.000000
# mean                   41.892124                  -87.659592
# std                     0.059498                    0.067986
# min                    41.650222                  -87.913625
# 25%                    41.878866                  -87.663518
# 50%                    41.892508                  -87.633308
# 75%                    41.922686                  -87.625192
# max                    42.021224                  -87.534903

# %%
data = data[['Trip Miles', 'Trip Total']]

data.shape
# Out:
# (865247, 2)

# %%
data.dropna(inplace=True)

data.isnull().sum()
# Out:
# Trip Miles    0
# Trip Total    0
# dtype: int64

# %%
x = data.iloc[:, :1].values
y = data.iloc[:, 1:2].values

print(x)
print(y)
# Out:
# [[ 0.09]
#  [ 3.  ]
#  [ 5.84]
#  ...
#  [17.44]
#  [ 3.07]
#  [ 1.49]]
# [[38.75]
#  [12.  ]
#  [26.7 ]
#  ...
#  [66.3 ]
#  [26.  ]
#  [12.25]]

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42
)

# %%
model = LinearRegression()

model.fit(x_train, y_train)

y_pred = model.predict(x_test)

y_pred
# Out:
# array([[42.1919655 ],
#        [28.15969042],
#        [12.27758623],
#        ...,
#        [ 9.81995614],
#        [48.63994124],
#        [48.11141863]])

# %%
model.score(x_test, y_test)
# Out:
# 0.1719224457128684

# %%
print(y_test)
print(y_pred)
# Out:
# [[31.25]
#  [24.98]
#  [ 8.75]
#  ...
#  [45.25]
#  [43.5 ]
#  [50.4 ]]
# [[42.1919655 ]
#  [28.15969042]
#  [12.27758623]
#  ...
#  [ 9.81995614]
#  [48.63994124]
#  [48.11141863]]

# %%
plt.scatter(x_train, y_train, color='blue')

plt.plot(
    x_train,
    model.predict(x_train),
    color='red'
)

plt.title('Trip Miles vs Trip Total (Training Set)')
plt.xlabel('Miles')
plt.ylabel('Total in dollars')

plt.show()

# %%
plt.scatter(x_test, y_test, color='blue')

plt.plot(
    x_test,
    model.predict(x_test),
    color='red'
)

plt.title('Trip Miles vs Trip Total (Testing Set)')
plt.xlabel('Miles')
plt.ylabel('Total in dollars')

plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %% [markdown]
# Enter the given dataset

# %%
data = pd.DataFrame({
    'Weight': [79, 69, 73, 95, 82, 55, 69, 71, 64, 69],
    'Height': [1.80, 1.68, 1.82, 1.70, 1.87, 1.55, 1.50, 1.78, 1.67, 1.64],
    'Age': [35, 39, 25, 60, 27, 18, 89, 42, 16, 52],
    'Gender': ['Male', 'Male', 'Male', 'Male', 'Male',
               'Female', 'Female', 'Female', 'Female', 'Female']
})

data
# Out:
#    Weight  Height  Age  Gender
# 0      79    1.80   35    Male
# 1      69    1.68   39    Male
# 2      73    1.82   25    Male
# 3      95    1.70   60    Male
# 4      82    1.87   27    Male
# 5      55    1.55   18  Female
# 6      69    1.50   89  Female
# 7      71    1.78   42  Female
# 8      64    1.67   16  Female
# 9      69    1.64   52  Female

# %% [markdown]
# Convert Gender

# %%
data['Gender'] = data['Gender'].replace({
    'Female': 0,
    'Male': 1
})

data
# Out:
# /tmp/ipykernel_2384/3578139063.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Gender'] = data['Gender'].replace({
#    Weight  Height  Age  Gender
# 0      79    1.80   35       1
# 1      69    1.68   39       1
# 2      73    1.82   25       1
# 3      95    1.70   60       1
# 4      82    1.87   27       1
# 5      55    1.55   18       0
# 6      69    1.50   89       0
# 7      71    1.78   42       0
# 8      64    1.67   16       0
# 9      69    1.64   52       0

# %% [markdown]
# Check shape

# %%
data.shape
# Out:
# (10, 4)

# %% [markdown]
# Check null values

# %%
data.isnull().sum()
# Out:
# Weight    0
# Height    0
# Age       0
# Gender    0
# dtype: int64

# %% [markdown]
# Separate X and Y

# %%
x = data.iloc[:, 1:].values
y = data.iloc[:, :1].values

print(x)
print(y)
# Out:
# [[ 1.8  35.    1.  ]
#  [ 1.68 39.    1.  ]
#  [ 1.82 25.    1.  ]
#  [ 1.7  60.    1.  ]
#  [ 1.87 27.    1.  ]
#  [ 1.55 18.    0.  ]
#  [ 1.5  89.    0.  ]
#  [ 1.78 42.    0.  ]
#  [ 1.67 16.    0.  ]
#  [ 1.64 52.    0.  ]]
# [[79]
#  [69]
#  [73]
#  [95]
#  [82]
#  [55]
#  [69]
#  [71]
#  [64]
#  [69]]

# %% [markdown]
# Split training and testing dat

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42
)

# %% [markdown]
# create Linear Regression model

# %%
model = LinearRegression()

model.fit(x_train, y_train)

y_pred = model.predict(x_test)

y_pred
# Out:
# array([[56.85651025],
#        [79.10576115]])

# %% [markdown]
# Print actual values

# %%
print(y_test)
# Out:
# [[64]
#  [69]]

# %% [markdown]
# Print predicted values

# %%
print(y_pred)
# Out:
# [[56.85651025]
#  [79.10576115]]

# %% [markdown]
# Check model score

# %%
model.score(x_test, y_test)
# Out:
# -11.252468343750825

# %% [markdown]
# Training graph
#
# Because this is multiple linear regression, we can show Height against Weight while keeping Age and Gender fixed

# %%
import numpy as np

x_train_height = x_train[:, 0]

plt.scatter(
    x_train_height,
    y_train,
    color='blue',
    label='Actual Weight'
)

mean_age = x_train[:, 1].mean()

mode_gender = pd.Series(
    x_train[:, 2].astype(int)
).mode()[0]

height_range = np.linspace(
    x_train_height.min(),
    x_train_height.max(),
    100
)

regression_data = np.array([
    [h, mean_age, mode_gender]
    for h in height_range
])

predicted_weight = model.predict(regression_data)

plt.plot(
    height_range,
    predicted_weight,
    color='red',
    label='Regression Line'
)

plt.title('Weight vs Height (Training Set)')
plt.xlabel('Height (meters)')
plt.ylabel('Weight (kg)')
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# Testing graph

# %%
x_test_height = x_test[:, 0]

plt.scatter(
    x_test_height,
    y_test,
    color='blue',
    label='Actual Weight'
)

height_range_test = np.linspace(
    x_test_height.min(),
    x_test_height.max(),
    100
)

regression_data_test = np.array([
    [h, mean_age, mode_gender]
    for h in height_range_test
])

predicted_weight_test = model.predict(
    regression_data_test
)

plt.plot(
    height_range_test,
    predicted_weight_test,
    color='red',
    label='Regression Line'
)

plt.title('Weight vs Height (Testing Set)')
plt.xlabel('Height (meters)')
plt.ylabel('Weight (kg)')
plt.legend()
plt.grid(True)

plt.show()
